# %% [markdown]
# # Let us bring in a dataset from kaggle

# %%
# let us install kaggle library
# !pip install kaggle
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# This block is used for uploading the api key associated with my account
from google.colab import files
uploaded = files.upload()
for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
  
# Then move kaggle.json into the folder where the API expects to find it.
# !mkdir -p ~/.kaggle/ && mv kaggle.json ~/.kaggle/ && chmod 600 ~/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-b388b7f2-dcd7-40fb-ba62-68d706906c23" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b388b7f2-dcd7-40fb-ba62-68d706906c23">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# User uploaded file "kaggle.json" with length 74 bytes

# %%
# This block shows some of the datasets
# it is just proving that the api key worked
# !kaggle datasets list
# Out:
# ref                                                            title                                                size  lastUpdated          downloadCount  voteCount  usabilityRating
# -------------------------------------------------------------  --------------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# kaggleashwin/population-dataset                                World Population by Countries Dataset (1960-2021)    69KB  2022-08-31 05:30:26           1303         63  1.0
# iamsouravbanerjee/house-rent-prediction-dataset                House Rent Prediction Dataset                        82KB  2022-08-20 13:49:03           9487        252  1.0
# iamsouravbanerjee/world-population-dataset                     World Population Dataset                             17KB  2022-08-31 11:20:04           3247        119  1.0
# ...

# %%
# # This is where you will have to rewrite 

# Brought this from the kaggle page
# https://www.kaggle.com/datasets/yasserh/wine-quality-dataset
# !kaggle datasets download -d yasserh/wine-quality-dataset
# Out:
# ...
#   0% 0.00/21.5k [00:00<?, ?B/s]
# 100% 21.5k/21.5k [00:00<00:00, 14.8MB/s]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Let us extract the contents of the zip file

# %%
from zipfile import ZipFile
#Extracting the dataset contents
zipFilePath='/content/wine-quality-dataset.zip'
zipFileObj=ZipFile(file=zipFilePath)
zipFileObj.extractall('/tmp/dataset')

# %%
! pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd
df = pd.read_csv('/tmp/dataset/WineQT.csv')

# %%
df.head(3)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# 2      9.8        5   2

# %%
df.tail(4)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1139                 28.0                  38.0  0.99651  3.42       0.82
# 1140                 32.0                  44.0  0.99490  3.45       0.58
# 1141                 39.0                  51.0  0.99512  3.52       0.76
# 1142                 32.0                  44.0  0.99547  3.57       0.71
#
#       alcohol  quality    Id
# 1139      9.5        6  1593
# 1140     10.5        5  1594
# 1141     11.2        6  1595
# 1142     10.2        5  1597

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'Id'],
#       dtype='object')

# %%
df[['fixed acidity', 'volatile acidity']] [2:4]
# Out:
#    fixed acidity  volatile acidity
# 2            7.8              0.76
# 3           11.2              0.28

# %%
df.iloc[2:4, 2:6]
# Out:
#    citric acid  residual sugar  chlorides  free sulfur dioxide
# 2         0.04             2.3      0.092                 15.0
# 3         0.56             1.9      0.075                 17.0

# %%
df.loc[(df['fixed acidity']==11.2) & (df['volatile acidity']==0.28)]
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 3           11.2              0.28         0.56             1.9      0.075
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 3                 17.0                  60.0    0.998  3.16       0.58
#
#    alcohol  quality  Id
# 3      9.8        6   3

# %%
df.loc[ (df['fixed acidity']==8.1) & (df['volatile acidity']==0.28),['free sulfur dioxide','pH']]=[100,200]

# %%
df.loc[(df['fixed acidity']==8.1) & (df['volatile acidity']==0.28)]
# Out:
# Empty DataFrame
# Columns: [fixed acidity, volatile acidity, citric acid, residual sugar, chlorides, free sulfur dioxide, total sulfur dioxide, density, pH, sulphates, alcohol, quality, Id]
# Index: []

# %%
df[["fixed acidity"]].mean()
# Out:
# fixed acidity    8.311111
# dtype: float64

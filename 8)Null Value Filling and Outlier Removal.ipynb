# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('/Productivity and Happiness Dataset with Outliers.csv')
df.head()
# Out:
#        Luck  Hardwork  Smartwork   Success
# 0  1.057725  1.301622   8.354773  5.031879
# 1  5.625179  5.095069   4.201305  5.549476
# 2  8.809968  9.756279   1.925934       NaN
# 3  9.837436  2.630020   3.155369  4.638813
# 4  6.342820  1.277968   5.940568  4.689938

# %% [markdown]
# At first let us see how many nan values are there

# %%
# when there are nan values
nansInLuck=df['Luck'].isna().sum()
nansInHardwork=df['Hardwork'].isna().sum()
nansInSmartwork=df['Smartwork'].isna().sum()
nansInSuccess=df['Success'].isna().sum()

print(f'nansInLuck={nansInLuck}')
print(f'nansInHardwork={nansInHardwork}')
print(f'nansInSmartwork={nansInSmartwork}')
print(f'nansInSuccess={nansInSuccess}')
# Out:
# nansInLuck=0
# nansInHardwork=0
# nansInSmartwork=0
# nansInSuccess=2

# %%
# we may deal with the null values in  3 ways

# df['Success']=df['Success'].fillna(df['Success'].mean())
df['Success']=df['Success'].fillna(method="ffill")
#df=df.dropna()

# %%
# when there are nan values
nansInLuck=df['Luck'].isna().sum()
nansInHardwork=df['Hardwork'].isna().sum()
nansInSmartwork=df['Smartwork'].isna().sum()
nansInSuccess=df['Success'].isna().sum()
print(f'nansInLuck={nansInLuck}')
print(f'nansInHardwork={nansInHardwork}')
print(f'nansInSmartwork={nansInSmartwork}')
print(f'nansInSuccess={nansInSuccess}')
# Out:
# nansInLuck=0
# nansInHardwork=0
# nansInSmartwork=0
# nansInSuccess=0

# %% [markdown]
# Now let us deal with the outliers

# %%
# Visualization Method
import seaborn as sns
sns.boxplot(df['Success'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df.loc[(df['Success']>10)]
# Out:
#          Luck  Hardwork  Smartwork    Success
# 67   6.010191  3.397514   2.206487  15.000000
# 165  7.949429  9.607387   9.754797  10.310856
# 203  7.355063  6.776454   9.936102  12.000000
# 218  4.661140  4.472170   3.547676  20.000000

# %%
df=df.drop(labels=[67,165,203,218], axis=0)

# %%
df.loc[(df['Success']>10)]
# Out:
# Empty DataFrame
# Columns: [Luck, Hardwork, Smartwork, Success]
# Index: []

# %%
X = df[['Luck', 'Hardwork','Smartwork']]
Y = df['Success']

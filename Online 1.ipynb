# %%
# let us install kaggle library
# !pip install kaggle
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# This block is used for uploading the api key associated with my account
from google.colab import files
uploaded = files.upload()
for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
  
# Then move kaggle.json into the folder where the API expects to find it.
# !mkdir -p ~/.kaggle/ && mv kaggle.json ~/.kaggle/ && chmod 600 ~/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-294e5044-daa3-44f1-abc0-377014beee5c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-294e5044-daa3-44f1-abc0-377014beee5c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# This block shows some of the datasets
# it is just proving that the api key worked
# !kaggle datasets list
# Out:
# ref                                                            title                                                size  lastUpdated          downloadCount  voteCount  usabilityRating
# -------------------------------------------------------------  --------------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# iamsouravbanerjee/world-population-dataset                     World Population Dataset                             17KB  2022-08-31 11:20:04           6971        215  1.0
# kaggleashwin/population-dataset                                World Population by Countries Dataset (1960-2021)    69KB  2022-08-31 05:30:26           1734         74  1.0
# iamsouravbanerjee/house-rent-prediction-dataset                House Rent Prediction Dataset                        82KB  2022-08-20 13:49:03          12743        321  1.0
# ...

# %%
# !kaggle kernels output testpython/linear-regression-with-single-variable -p /path/to/dest
# Out:
# Kernel log downloaded to /path/to/dest/linear-regression-with-single-variable.log

# %%
import pandas as pd

# %%
df_train = pd.read_csv('/train.csv')
df_train
# Out:
#         x          y
# 0    24.0  21.549452
# 1    50.0  47.464463
# 2    15.0  17.218656
# 3    38.0  36.586398
# 4    87.0  87.288984
# ..    ...        ...
# 695  58.0  58.595006
# 696  93.0  94.625094
# 697  82.0  88.603770
# 698  66.0  63.648685
# 699  97.0  94.975266
#
# [700 rows x 2 columns]

# %%
df_train.isnull().sum()
# Out:
# x    0
# y    1
# dtype: int64

# %%
df_train['y']=df_train['y'].fillna(df_train['y'].mean())

# %%
df_test = pd.read_csv('/test.csv')
df_test
# Out:
#       x          y
# 0    77  79.775152
# 1    21  23.177279
# 2    22  25.609262
# 3    20  17.857388
# 4    36  41.849864
# ..   ..        ...
# 295  71  68.545888
# 296  46  47.334876
# 297  55  54.090637
# 298  62  63.297171
# 299  47  52.459467
#
# [300 rows x 2 columns]

# %%
df_test.isnull().sum()
# Out:
# x    0
# y    0
# dtype: int64

# %%
y = df_train['y']
X = df_train['x']

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly = PolynomialFeatures(degree=2, include_bias=False)

# %%
poly_features = poly.fit_transform(X.values.reshape(-1, 1))

# %%
#poly_features_y = poly.fit_transform(y.values.reshape(-1, 1))

# %%
poly_features
# Out:
# array([[  24.,  576.],
#        [  50., 2500.],
#        [  15.,  225.],
#        ...,
#        [  82., 6724.],
#        [  66., 4356.],
#        [  97., 9409.]])

# %%
# !pip install dipy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 7.8 MB 2.0 MB/s
# ...

# %%
X
# Out:
# 0      24.0
# 1      50.0
# 2      15.0
# 3      38.0
# 4      87.0
#        ...
# 695    58.0
# 696    93.0
# 697    82.0
# 698    66.0
# 699    97.0
# Name: x, Length: 700, dtype: float64

# %%
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
import pandas as pd

# %%
poly_reg_model = LinearRegression()

# %%
poly_reg_model.fit(poly_features, y)
# Out:
# LinearRegression()

# %%
y_predicted = poly_reg_model.predict(poly_features)

# %%
y_predicted

# %%
y
# Out:
# 0      21.549452
# 1      47.464463
# 2      17.218656
# 3      36.586398
# 4      87.288984
#          ...
# 695    58.595006
# 696    94.625094
# 697    88.603770
# 698    63.648685
# 699    94.975266
# Name: y, Length: 700, dtype: float64

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
# error calculation
mae=mean_absolute_error(y,y_predicted)
mse=mean_squared_error(y,y_predicted)
rmse=np.sqrt(mse) # finds the root mean square error

# %%
print(mae)
print(mse)
print(rmse)
# Out:
# 2.231299866287653
# 7.846931171377086
# 2.801237435737479

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()

# %%
y=df_train['y'].values.reshape(-1,1)
x=df_train['x'].values.reshape(-1,1)

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)

# %%
regressor.fit(x,y)  # fits/trains the model
# Out:
# LinearRegression()

# %%
y_pred=regressor.predict(X_test)  # gives the predicted result

# %%
# error calculation
mae=mean_absolute_error(y_test,y_pred)
mse=mean_squared_error(y_test,y_pred)
rmse=np.sqrt(mse) # finds the root mean square error

# %%
print(mae)
print(mse)
print(rmse)
# Out:
# 23.53074821709846
# 765.2362307187034
# 27.662903512081
